# %% [markdown]
# Mixed Variables
# Feature Engineering for Machine Learning Course
#
# Mixed variables are those whose values contain both numbers and labels.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/lalitrajput/Tools/ML-Notes-and-Projects/Basic Machine Learning/FeatureEngg/Datasets/sample_s2.csv')
df.info
# Out:
# <bound method DataFrame.info of               id open_il_24m
# 0        1077501           C
# 1        1077430           A
# 2        1077175           A
# 3        1076863           A
# 4        1075358           A
# ...          ...         ...
# 887374  36371250           A
# 887375  36441262           A
# 887376  36271333           C
# 887377  36490806           C
# 887378  36271262           A
#
# [887379 rows x 2 columns]>

# %%
df.head()
# Out:
#         id open_il_24m
# 0  1077501           C
# 1  1077430           A
# 2  1077175           A
# 3  1076863           A
# 4  1075358           A

# %%
df['open_il_24m'].unique
# Out:
# <bound method Series.unique of 0         C
# 1         A
# 2         A
# 3         A
# 4         A
#          ..
# 887374    A
# 887375    A
# 887376    C
# 887377    C
# 887378    A
# Name: open_il_24m, Length: 887379, dtype: object>

# %%
df['open_il_24m'].value_counts()
# Out:
# open_il_24m
# A       500548
# C       300000
# B        65459
# 1.0       6436
# 0.0       5481
# 2.0       4448
# 3.0       2468
# 4.0       1249
# 5.0        606
# 6.0        309
# 7.0        163
# 8.0         81
# 9.0         47
# 10.0        28
# 11.0        23
# 12.0        17
# 13.0         7
# 14.0         6
# 15.0         2
# 19.0         1
# Name: count, dtype: int64

# %%
df['open_il_24m'].value_counts().plot(kind='bar')
plt.show()
